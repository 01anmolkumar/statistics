# %% [markdown]
# Measures of cenyral tendency

# %%
#mean/average

age =[28,56,35,28,76,89]

# %%
(28+56+35+28+76+89) / 6
# Out:
# 52.0

# %%
import numpy as np

# %%
np.mean(age)
# Out:
# 52.0

# %%
height=[160,120,125,340]

# %%
np.mean(height)
# Out:
# 186.25

# %%
#median
nos=[4,2,3,7,8]
np.median(nos)
# Out:
# 4.0

# %%
#mode
nos=[4,2,3,3,7,8]
np.mode(nos) # 'numpy' has no attribute 'mode
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 3
#       1 #mode
#       2 nos=[4,2,3,3,7,8]
# ----> 3 np.mode(nos) # 'numpy' has no attribute 'mode
#
# File C:\Python312\Lib\site-packages\numpy\__init__.py:347, in __getattr__(attr)
#     344     "Removed in NumPy 1.25.0"
#     345     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 347 raise AttributeError("module {!r} has no attribute "
#     348                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'mode'

# %%
from scipy import stats

# %%
stats.mode(nos)
# Out:
# ModeResult(mode=3, count=2)

# %%
import statistics

# %%
statistics.mode(nos)
# Out:
# 3

# %%
height=[160,120,125,340,150]
np.mean(height)
# Out:
# 179.0

# %%
#outlier affect the maean and a not not median
np.median(height)
# Out:
# 150.0

# %%
#after outlier
height =[1600,120,125,340,150]
np.mean(height)
# Out:
# 467.0

# %%
np.median(height)
# Out:
# 150.0
